# %%
def Funcion(num1):
  
  print("La funcion de x es:",(x**2)+(3*x)+3)
  return (x**2)+(3*x)+3

print("Sea la funcion x^2+3x+3")
x=int(input("Introduce el valor de x:"))

fx=Funcion(x)

A=[contador]
contador= fx
while contador >=-4 and contador<= 10:

    contador = contador + 1       
    
    print(A)
    if contador >=30:
      continue

    print(contador)
# Out:
# Sea la funcion x^2+3x+3
# Introduce el valor de x:5
# La funcion de x es: 43
