# %%
while 1:
  print("Este programa calcula las raices de ax^2+bx+c=0")
  a=float(input("Introduce el valor de a:"))
  b=float(input("Introduce el valor de b:"))
  c=float(input("Introduce el valor de c:"))

  z=(b*b)-4*a*c

  if z<0:
   
    print("Error, el discriminante debe ser positivo")
  
  else: 
    x1=((-b+(d)**0.5))/(2*a)

    x2=((-b-(d)**0.5))/(2*a)
    print("Solucion x1:",x1)
    print("Solucion x2:",x2)

    break
# Out:
# Este programa calcula las raices de ax^2+bx+c=0
# Introduce el valor de a:2
# Introduce el valor de b:5
# Introduce el valor de c:3
# Solucion x1: 2.1134060117684275
# Solucion x2: -4.6134060117684275
